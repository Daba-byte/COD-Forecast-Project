# %%
#### 다음 실습 코드는 학습 목적으로만 사용 바랍니다. 문의 : audit@korea.ac.kr 임성열 Ph.D.

'''Python 3.13에서는 아직 TensorFlow가 공식 지원 안됨. Python 3.11 이하 (특히 3.9, 3.10, 3.11) 사용 권고 

# 여러 버전의 Python을 설치하고 관리해야 한다면, pyenv 또는 anaconda 등으로 여러 버전의 Python 설치 후 프로젝트별 버전 전환 관리할 수 있음
# 또는 직접 수동으로 각각 Python 버전 설치도 가능하나 각 실행 파일 디렉토리 위치 경로를 수작업으로 관리 필요

# 파이썬 버전 제어 및 범용 개발이 중심이라면 → 🧑‍💻 pyenv + venv/poetry 조합 추천
# 데이터 과학/머신러닝 중심이라면 → 🎯 Anaconda (또는 Miniconda) 권장
# 빠른 개발 및 배포 → 📦 forge는 최근 등장한 관리 도구로 Jupyter 환경 설정 별도 필요, 아직 패키지 배포 자동화 및 GPU 지원 미비

# Python 버전 낮추기 또는 여러 버전 이용 (예시) : 

# 🧑‍💻 pyenv 설치 후, pyenv install 3.10.13
# pyenv global 3.10.13   # 또는 pyenv local 3.10.13 (현재 폴더만)
# pip install numpy matplotlib pandas scikit-learn tensorflow

# 🎯 anaconda (https://www.anaconda.com/products/distribution) 설치 후 
# conda create -n tf python=3.10.13
# conda activate tf
# pip install numpy matplotlib pandas scikit-learn tensorflow

# 🧪 모두 다 설치했다면 → 하나의 목적에만 집중해 사용하는 것이 충돌 방지에 좋음'''

# Installing the packeges
'''graphviz는 먼저 OS 패키지 설치 필요 (리눅스 : apt-get install graphviz, 맥 OS : brew install graphviz)
# 윈도우는 다음과 같이 직접 설치 필요
 1. Graphviz 공식 다운로드 페이지 접속 (https://graphviz.org/download/)
 2. Windows installer (exe) 파일 다운로드 후 설치
 3. 설치 경로(C:\\Program Files\\Graphviz\\bin)를 환경 변수 PATH에 추가'''
 
# !python -m pip uninstall -y tensorflow keras
# !python -m pip install -U "tensorflow>=2.20.0" "keras>=3.11,<4"
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping keras as it is not installed.
# Collecting tensorflow>=2.20.0
#   Downloading tensorflow-2.21.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (4.4 kB)
# Collecting keras<4,>=3.11
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting absl-py (from keras<4,>=3.11)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from keras<4,>=3.11) (2.1.3)
# Collecting rich (from keras<4,>=3.11)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras<4,>=3.11)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting h5py (from keras<4,>=3.11)
#   Downloading h5py-3.16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting optree (from keras<4,>=3.11)
#   Downloading optree-0.19.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting ml-dtypes (from keras<4,>=3.11)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Requirement already satisfied: packaging in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from keras<4,>=3.11) (26.0)
# Collecting astunparse>=1.6.0 (from tensorflow>=2.20.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow>=2.20.0)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow>=2.20.0)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow>=2.20.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow>=2.20.0)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow>=2.20.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from tensorflow>=2.20.0) (6.33.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from tensorflow>=2.20.0) (2.33.1)
# Collecting setuptools (from tensorflow>=2.20.0)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.12.0 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from tensorflow>=2.20.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow>=2.20.0)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from tensorflow>=2.20.0) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow>=2.20.0)
#   Downloading wrapt-2.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow>=2.20.0)
#   Downloading grpcio-1.80.0-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting h5py (from keras<4,>=3.11)
#   Downloading h5py-3.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow>=2.20.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow>=2.20.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow>=2.20.0) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow>=2.20.0) (2026.2.25)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow>=2.20.0)
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras<4,>=3.11)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/hyun/workspace/mlops/.venv/lib/python3.13/site-packages (from rich->keras<4,>=3.11) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras<4,>=3.11)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading keras-3.14.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.9 MB/s  0:00:00
# Downloading tensorflow-2.21.0-cp313-cp313-macosx_12_0_arm64.whl (223.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 MB 67.9 MB/s  0:00:03m0:00:0100:01
# Downloading grpcio-1.80.0-cp313-cp313-macosx_11_0_universal2.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 60.8 MB/s  0:00:00
# Downloading h5py-3.14.0-cp313-cp313-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 61.6 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp313-cp313-macosx_10_13_universal2.whl (676 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 49.1 MB/s  0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 65.6 MB/s  0:00:00 eta 0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp313-cp313-macosx_11_0_arm64.whl (61 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp313-cp313-macosx_11_0_arm64.whl (392 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, setuptools, optree, opt_einsum, ml-dtypes, mdurl, h5py, grpcio, google_pasta, gast, absl-py, markdown-it-py, astunparse, rich, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [tensorflow]1 [tensorflow]-py]
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.14.0 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 rich-14.3.3 setuptools-82.0.1 tensorflow-2.21.0 termcolor-3.3.0 wheel-0.46.3 wrapt-2.1.2

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
# Connectiing Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Loading the data
dataset = pd.read_csv('/Users/hyun/workspace/mlops/model_serving_rpt/server/uploaded_files/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Checking for missing values
# 2016년도이전 데이터에서 2번째 컬럼 값을 가져와서 저장합니다.
training_set = dataset[:'2016'].iloc[:,1:2].values
# 2017년도이후 데이터에서 2번째 컬럼 값을 가져와서 저장합니다.
test_set = dataset['2017':].iloc[:,1:2].values

# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
import os
import time
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# (진단/우회) 일반적으로 LSTM은 GPU 효율이 낮은 구조임, 맥에서 첫 배치 hang를 피하기 위한 설정 (리눅스나 윈도우에는 영향 없음)
# GPU/메탈 런타임에서 첫 배치가 멈추는 경우가 있어 CPU로 강제해 진단/우회 (GPU가 맞는 데이터 특성, 대형 행렬 곱 : CNN, Transformer, 대규모 벡터 연산)
# 모델/텐서 연산 전에 실행
try:
    tf.config.set_visible_devices([], "GPU") # GPU를 쓰기에는 너무 작은 데이터로 CPU로 처리 (2709 × 60 × 1)
except Exception:
    pass

# XLA(JIT) 관련 이슈를 배제하기 위해 비활성화
try:
    tf.config.optimizer.set_jit(False)
except Exception:
    pass

# Scaling the training set

sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set).astype(np.float32)

# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements
X_train = []
y_train = []
# LSTM 시계열 분석을 위해, Timesteps를 60으로 할 것이므로 60행 이후 데이터부터 사용 가능
# 데이터 셋을 보면, 2016년 데이터가 전체 2769개 존재함
# 데이터 길이에 맞게 자동 계산하도록 수정 (또는 2769로 하드코딩도 가능하나, 비추천)
for i in range(60, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.float32)

# Reshaping X_train for efficient modelling
# Timesteps와 MinMaxScaler 등을 적용한 대상 데이터를, LSTM Layer 입력에 용이하게 재배치
# shape[0]는 전체 행의 갯수, shape[1]은 전체 열의 갯수인데.. 상기 np 배열에 넣은 형태로 여기서는 잘라낸 Timesteps 갯수
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
# X_train = np.reshape(X_train, (2709,60,1))을 뜻하며, 2016년이전 2709개의 행을 60개씩 끊어낸 값 1행으로
# LSTM (시계열성 데이터 변경 이력 예측에 특화된 RNN모델) input_shape에 맞게 3차원 배열로 재구성

# (진단) 입력 확인
print("[debug] X_train:", X_train.shape, X_train.dtype, "finite:", np.isfinite(X_train).all())
print("[debug] y_train:", y_train.shape, y_train.dtype, "finite:", np.isfinite(y_train).all())
print("[debug] GPUs:", tf.config.list_physical_devices("GPU"))
print("[debug] CPUs:", tf.config.list_physical_devices("CPU"))

# The LSTM architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense

regressor = Sequential()

# 입력 정의 (X_train: (samples, timesteps, features) 가정)
regressor.add(Input(shape=(X_train.shape[1], 1)))

# First LSTM layer with Dropout regularisation
# 50개의 노드를 사용하여 RNN, LSTM 방식으로 입력층, 은닉층 생성
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# 전체 가능한 데이터 범위는 2709행에 대해서 60개 단위로 자동 계산되므로 생략
# 60개씩 끊어내서, 1개의 Feature에 대해서 예측

# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# The output layer
regressor.add(Dense(units=1))
# 최종 결과가 60개씩 시계열 이력 데이터를 끊어낸 단위에 대해 학습한 결과, 값 예측이므로 마지막 노드는 1개로 처리
# 단, MNIST 이미지 데이터와 같이, 0~9까지 표현을 위해 최종 노드를 사용하는 경우 10개 노드 필요

# Compiling the RNN
regressor.compile(optimizer='adam', loss='mean_squared_error')

# Fitting to the training set
# 시계열 데이터 특성상 shuffle=False 권장
# verbose=1 설정으로 epoch 진행 상황을 명확히 출력
# batch_size는 학습 속도에 영향을 미침
regressor.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    shuffle=False,
    verbose=1
)
# Out:
# [debug] X_train: (2709, 60, 1) float32 finite: True
# [debug] y_train: (2709,) float32 finite: True
# [debug] GPUs: []
# [debug] CPUs: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Epoch 1/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0099
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0127
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0092
# Epoch 4/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0091
# Epoch 5/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0074
# Epoch 6/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0074
# Epoch 7/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0071
# Epoch 8/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0080
# Epoch 9/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0081
# Epoch 10/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0097
# Epoch 11/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0134
# Epoch 12/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0169
# Epoch 13/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0218
# Epoch 14/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0261
# Epoch 15/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0318
# Epoch 16/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0295
# Epoch 17/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0283
# Epoch 18/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0249
# Epoch 19/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0220
# Epoch 20/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0219
# Epoch 21/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0232
# Epoch 22/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0225
# Epoch 23/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0200
# Epoch 24/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0210
# Epoch 25/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0183
# Epoch 26/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0175
# Epoch 27/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0191
# Epoch 28/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0177
# Epoch 29/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0163
# Epoch 30/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0172
# Epoch 31/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0155
# Epoch 32/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0159
# Epoch 33/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0146
# Epoch 34/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0136
# Epoch 35/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0133
# Epoch 36/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0131
# Epoch 37/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0130
# Epoch 38/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0125
# Epoch 39/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0120
# Epoch 40/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0106
# Epoch 41/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0090
# Epoch 42/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0086
# Epoch 43/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0087
# Epoch 44/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0092
# Epoch 45/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0096
# Epoch 46/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0078
# Epoch 47/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0067
# Epoch 48/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0068
# Epoch 49/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0067
# Epoch 50/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0065

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 22.316660578208687.

# %%
# 1. 모델 저장하기
from keras.models import load_model

# regressor.save('/content/drive/MyDrive/data/stock_lstm_model_nogpu.h5')
regressor.save('/Users/hyun/workspace/mlops/model_serving_rpt/server/model/stock_lstm_model_nogpu.keras')

# %%
# 2. 모델 불러오기
import pandas as pd
from keras.models import load_model

# Connectiing Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Loading the model
model = load_model('/Users/phoenix/Eagle/2026_MLOps/service_model/model_serving/server/model/stock_lstm_model_nogpu.keras')

# Loading the data
dataset = pd.read_csv('/Users/phoenix/Eagle/2026_MLOps/service_model/model_serving/server/uploaded_files/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])

# We have chosen 'High' attribute for prices.
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# 3. 모델 아키텍처 보기
from keras.utils import plot_model
import pydot
import graphviz

# plot_model(model, to_file='/content/drive/MyDrive/data/model.png')
# plot_model(model, to_file='/content/drive/MyDrive/data/model_shapes.png', show_shapes=True)

plot_model(model, to_file='/Users/phoenix/Eagle/2026_MLOps/service_model/model_serving/server/model-images/model_service.png')
plot_model(model, to_file='/Users/phoenix/Eagle/2026_MLOps/service_model/model_serving/server/model-images/model_shapes.png', show_shapes=True)

# %%
# 4. 모델 사용하기
'''사용 순서
1. 데이터 파일을 입력 받아서 IBM_2006-01-01_to_2018-01-01.csv
2. 로딩한 모델로 예측한 후에 stock_lstm_model.keras
3. 결과를 stock.png 파일로 생성하여 내보내는 순서'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# from keras.models import Sequential # 모델 학습 시에 사용하였으나, 모델을 재사용하는 것이므로 불필요
# from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional # 모델 학습 시에 사용하였으나, 모델을 재사용하는 것이므로 불필요
import math
from sklearn.metrics import mean_squared_error

# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
  # plt.show()
  # plt.savefig('/content/drive/MyDrive/data/stock.png')
    plt.savefig('/Users/phoenix/Eagle/2026_MLOps/service_model/model_serving/server/model-images/stock.png')  

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 3.1128447385802094.

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  3 2025, 18:38:25) [Clang 16.0.0 (clang-1600.0.26.6)]
